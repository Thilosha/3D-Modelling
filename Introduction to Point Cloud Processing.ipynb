# %%
import os

# Get the current working directory
current_dir = os.getcwd()

# Print the current working directory
print(current_dir)
# Out:
# C:\Users\thila

# %%
os.chdir('C:/Users/thila/PCD')

# %%
pip install open3d
# Out:
# Collecting open3d
#   Downloading open3d-0.17.0-cp39-cp39-win_amd64.whl (62.6 MB)
#      ---------------------------------------- 62.6/62.6 MB 4.2 MB/s eta 0:00:00
# Collecting nbformat==5.7.0
#   Downloading nbformat-5.7.0-py3-none-any.whl (77 kB)
#      ---------------------------------------- 77.1/77.1 kB 2.2 MB/s eta 0:00:00
# Collecting configargparse
#   Downloading ConfigArgParse-1.5.3-py3-none-any.whl (20 kB)
# Collecting werkzeug>=2.2.3
#   Downloading Werkzeug-2.3.6-py3-none-any.whl (242 kB)
#      -------------------------------------- 242.5/242.5 kB 7.5 MB/s eta 0:00:00
# Collecting ipywidgets>=8.0.4
#   Downloading ipywidgets-8.0.6-py3-none-any.whl (138 kB)
#      -------------------------------------- 138.3/138.3 kB 8.5 MB/s eta 0:00:00
# Collecting dash>=2.6.0
#   Downloading dash-2.10.2-py3-none-any.whl (10.3 MB)
#      ---------------------------------------- 10.3/10.3 MB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.18.0 in c:\users\thila\anaconda3\lib\site-packages (from open3d) (1.21.5)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\thila\anaconda3\lib\site-packages (from nbformat==5.7.0->open3d) (4.16.0)
# Requirement already satisfied: traitlets>=5.1 in c:\users\thila\anaconda3\lib\site-packages (from nbformat==5.7.0->open3d) (5.1.1)
# Requirement already satisfied: jupyter-core in c:\users\thila\anaconda3\lib\site-packages (from nbformat==5.7.0->open3d) (4.11.1)
# Requirement already satisfied: fastjsonschema in c:\users\thila\anaconda3\lib\site-packages (from nbformat==5.7.0->open3d) (2.16.2)
# Requirement already satisfied: Flask<2.3.0,>=1.0.4 in c:\users\thila\anaconda3\lib\site-packages (from dash>=2.6.0->open3d) (1.1.2)
# Collecting dash-html-components==2.0.0
#   Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\thila\anaconda3\lib\site-packages (from dash>=2.6.0->open3d) (5.9.0)
# Collecting werkzeug>=2.2.3
#   Downloading Werkzeug-2.2.3-py3-none-any.whl (233 kB)
#      -------------------------------------- 233.6/233.6 kB 7.2 MB/s eta 0:00:00
# Collecting dash-table==5.0.0
#   Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Collecting dash-core-components==2.0.0
#   Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\thila\anaconda3\lib\site-packages (from ipywidgets>=8.0.4->open3d) (7.31.1)
# Collecting jupyterlab-widgets~=3.0.7
#   Downloading jupyterlab_widgets-3.0.7-py3-none-any.whl (198 kB)
#      ------------------------------------- 198.2/198.2 kB 11.7 MB/s eta 0:00:00
# Collecting widgetsnbextension~=4.0.7
#   Downloading widgetsnbextension-4.0.7-py3-none-any.whl (2.1 MB)
#      ---------------------------------------- 2.1/2.1 MB 9.6 MB/s eta 0:00:00
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\thila\anaconda3\lib\site-packages (from ipywidgets>=8.0.4->open3d) (6.15.2)
# Collecting MarkupSafe>=2.1.1
#   Downloading MarkupSafe-2.1.3-cp39-cp39-win_amd64.whl (17 kB)
# Requirement already satisfied: click>=5.1 in c:\users\thila\anaconda3\lib\site-packages (from Flask<2.3.0,>=1.0.4->dash>=2.6.0->open3d) (8.0.4)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\thila\anaconda3\lib\site-packages (from Flask<2.3.0,>=1.0.4->dash>=2.6.0->open3d) (2.11.3)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\thila\anaconda3\lib\site-packages (from Flask<2.3.0,>=1.0.4->dash>=2.6.0->open3d) (2.0.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\thila\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=8.0.4->open3d) (0.1.6)
# Requirement already satisfied: pyzmq>=17 in c:\users\thila\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=8.0.4->open3d) (23.2.0)
# Requirement already satisfied: nest-asyncio in c:\users\thila\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=8.0.4->open3d) (1.5.5)
# Requirement already satisfied: packaging in c:\users\thila\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=8.0.4->open3d) (21.3)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\thila\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=8.0.4->open3d) (7.3.4)
# Requirement already satisfied: debugpy>=1.0 in c:\users\thila\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=8.0.4->open3d) (1.5.1)
# Requirement already satisfied: tornado>=6.1 in c:\users\thila\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=8.0.4->open3d) (6.1)
# Requirement already satisfied: psutil in c:\users\thila\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=8.0.4->open3d) (5.9.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\thila\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (3.0.20)
# Requirement already satisfied: pygments in c:\users\thila\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (2.11.2)
# Requirement already satisfied: pickleshare in c:\users\thila\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in c:\users\thila\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.18.1)
# Requirement already satisfied: decorator in c:\users\thila\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (5.1.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\thila\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (63.4.1)
# Requirement already satisfied: colorama in c:\users\thila\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.4.5)
# Requirement already satisfied: backcall in c:\users\thila\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.2.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\thila\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat==5.7.0->open3d) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\thila\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat==5.7.0->open3d) (0.18.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\thila\anaconda3\lib\site-packages (from plotly>=5.0.0->dash>=2.6.0->open3d) (8.0.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\thila\anaconda3\lib\site-packages (from jupyter-core->nbformat==5.7.0->open3d) (302)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\thila\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.8.3)
# Requirement already satisfied: entrypoints in c:\users\thila\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=8.0.4->open3d) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\thila\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=8.0.4->open3d) (2.8.2)
# Requirement already satisfied: wcwidth in c:\users\thila\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.2.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\thila\anaconda3\lib\site-packages (from packaging->ipykernel>=4.5.1->ipywidgets>=8.0.4->open3d) (3.0.9)
# Requirement already satisfied: six>=1.5 in c:\users\thila\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=8.0.4->open3d) (1.16.0)
# Installing collected packages: dash-table, dash-html-components, dash-core-components, widgetsnbextension, MarkupSafe, jupyterlab-widgets, configargparse, werkzeug, nbformat, ipywidgets, dash, open3d
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.5.2
#     Uninstalling widgetsnbextension-3.5.2:
#       Successfully uninstalled widgetsnbextension-3.5.2
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 2.0.1
#     Uninstalling MarkupSafe-2.0.1:
#       Successfully uninstalled MarkupSafe-2.0.1
#   Attempting uninstall: jupyterlab-widgets
#     Found existing installation: jupyterlab-widgets 1.0.0
#     Uninstalling jupyterlab-widgets-1.0.0:
#       Successfully uninstalled jupyterlab-widgets-1.0.0
#   Attempting uninstall: werkzeug
#     Found existing installation: Werkzeug 2.0.3
#     Uninstalling Werkzeug-2.0.3:
#       Successfully uninstalled Werkzeug-2.0.3
#   Attempting uninstall: nbformat
#     Found existing installation: nbformat 5.5.0
#     Uninstalling nbformat-5.5.0:
#       Successfully uninstalled nbformat-5.5.0
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.6.5
#     Uninstalling ipywidgets-7.6.5:
#       Successfully uninstalled ipywidgets-7.6.5
# Successfully installed MarkupSafe-2.1.3 configargparse-1.5.3 dash-2.10.2 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 ipywidgets-8.0.6 jupyterlab-widgets-3.0.7 nbformat-5.7.0 open3d-0.17.0 werkzeug-2.2.3 widgetsnbextension-4.0.7
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# anaconda-project 0.11.1 requires ruamel-yaml, which is not installed.
# conda-repo-cli 1.0.20 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.20 requires nbformat==5.4.0, but you have nbformat 5.7.0 which is incompatible.

# %%
# !pip uninstall markupsafe
# !pip install markupsafe

# %%
import numpy as np
import matplotlib.pyplot as plt
import open3d as o3d
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
number_points = 5
pcd = np.random.rand(number_points, 3)  # uniform distribution over [0, 1)
print(pcd)
# Out:
# [[0.70348476 0.61219477 0.38060805]
#  [0.2132776  0.42541349 0.32222519]
#  [0.2816589  0.75609731 0.07613974]
#  [0.20534774 0.56686186 0.70913713]
#  [0.14391201 0.16953053 0.25450239]]

# %%
# Create Figure:
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
ax.scatter3D(pcd[:, 0], pcd[:, 1], pcd[:, 2])
# label the axes
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")
ax.set_title("Random Point Cloud")
# display:
plt.show()

# %%
bunny = o3d.data.BunnyMesh()
mesh = o3d.io.read_triangle_mesh("C:/Users/thila/PCD/bunny.ply")

# %%
mesh.compute_vertex_normals() # compute normals for vertices or faces
o3d.visualization.draw_geometries([mesh])

# %%
# Sample 1000 points:
pcd = mesh.sample_points_uniformly(number_of_points=1000)

# visualize:
o3d.visualization.draw_geometries([pcd])

# %%
# Save into ply file:
o3d.io.write_point_cloud("C:/Users/thila/PCD/output/bunny_pcd.ply", pcd)
# Out:
# True

# %%
# Create numpy pointcloud:
number_points = 2000
pcd_np = np.random.rand(number_points, 3)

# Convert to Open3D.PointCLoud:
pcd_o3d = o3d.geometry.PointCloud()  # create point cloud object
pcd_o3d.points = o3d.utility.Vector3dVector(pcd_np)  # set pcd_np as the point cloud points

# Visualize:
o3d.visualization.draw_geometries([pcd_o3d])

# %%
# Read the bunny point cloud file:
pcd_o3d = o3d.io.read_point_cloud("C:/Users/thila/PCD/bunny.ply")

# Convert the open3d object to numpy:
pcd_np = np.asarray(pcd_o3d.points)

# Display using matplotlib:
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
ax.scatter3D(pcd_np[:, 0], pcd_np[:, 2], pcd_np[:, 1])
# label the axes
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")
ax.set_title("Bunny Point Cloud")
# display:
plt.show()
